# %% [markdown]
# #functions
# 1. what is the difference between python and function?
#  > gjnnjmmhhnk
# 2. bkbkbkbbbkbb
# >  klnklnlknlnlk

# %%
#question

'''
this is answer
'''
"""
this is answer
"""
# Out:
# '\nthis is answer\n'
